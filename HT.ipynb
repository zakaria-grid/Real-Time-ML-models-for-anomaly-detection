# %%
# %matplotlib notebook

# %%
from skmultiflow.trees.hoeffding_adaptive_tree import HAT

# %%
from skmultiflow.data.file_stream import FileStream

# %%
from skmultiflow.evaluation.evaluate_prequential import EvaluatePrequential

# %%
#stream = FileStream("normal_Sing2.csv", -1, 1)

# %%
#stream = FileStream("C:/Users/zakaria.elmrabet/.conda/pkgs/scikit-multiflow-0.3.0-py37hf75dd32_0/Lib/site-packages/skmultiflow/data/datasets/covtype.csv", -1, 1)

# %%
stream = FileStream("C:/Users/zakaria.elmrabet/Dropbox/Research/2019/Smart Grid Research/Papers/FDI Extended/Resutls/Dataset/IAO_H_50s_5_14/normal_Sing2.csv",1500,1)

# %%
stream.prepare_for_use()

# %%
classifier = HAT(split_confidence=0.2,split_criterion='gini')

# %%
evaluator = EvaluatePrequential(pretrain_size=2000, max_samples=50000, batch_size=1, n_wait=200, max_time=1000,output_file="results.txt", show_plot=True, metrics=['kappa', 'kappa_t', 'accuracy','running_time'])

# %%
evaluator.evaluate(stream=stream, model=classifier)
# Out:
# <img src="data:image/png;base64,..." width="900">
# Prequential Evaluation
# Evaluating 1 target(s).
# Pre-training on 2000 sample(s).
# Evaluating...
#  #################### [100%] [123.56s]
# Processed samples: 3998
# Mean performance:
# M0 - Accuracy     : 0.6839
# M0 - Kappa        : 0.0000
# M0 - Kappa T      : 0.2042
# M0 - Training time (s)  : 104.28
# M0 - Testing time  (s)  : 11.67
# M0 - Total time    (s)  : 115.95
# [HAT(binary_split=False, grace_period=200, leaf_prediction='nba',
#      max_byte_size=33554432, memory_estimate_period=1000000, nb_threshold=0,
#      no_preprune=False, nominal_attributes=None, remove_poor_atts=False,
#      split_confidence=0.2, split_criterion='gini', stop_mem_management=False,
#      tie_threshold=0.05)]
